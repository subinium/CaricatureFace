# %%
import numpy as np
from PIL import Image
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
img = Image.open('exp/images/2a7a46104330addb2d3e6777f78856b5.jpg')
img_np = np.array(img)

# %%
plt.imshow(img_np)

# %%
lm = np.load('./exp/landmarks/2a7a46104330addb2d3e6777f78856b5.jpg.npy')

# %%
lm_r = np.load('./record/lrecord/2a7a46104330addb2d3e6777f78856b5_l.npy')

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

ax.imshow(img_np)
ax.scatter(lm[:,0], lm[:,1], c='red')

ax.axis('off')
plt.show()
